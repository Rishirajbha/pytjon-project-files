# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Car Sales Dataset

# %%
data= pd.read_excel("C:\\Users\\rjris\\Downloads\\car_sales_data_sample.xlsx") 
print(data)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
for col in data.columns: # for checking columns
    print(col)
# Out:
# ORDERNUMBER
# QUANTITYORDERED
# PRICEEACH
# ORDERLINENUMBER
# SALES
# ORDERDATE
# STATUS
# QTR_ID
# MONTH_ID
# YEAR_ID
# PRODUCTLINE
# MSRP
# PRODUCTCODE
# CUSTOMERNAME
# ADDRESSLINE1
# ADDRESSLINE2
# CITY
# STATE
# POSTALCODE
# COUNTRY
# TERRITORY
# CONTACTLASTNAME
# CONTACTFIRSTNAME
# DEALSIZE

# %%
list(data.columns) # for checking columns
# Out:
# ['ORDERNUMBER',
#  'QUANTITYORDERED',
#  'PRICEEACH',
#  'ORDERLINENUMBER',
#  'SALES',
#  'ORDERDATE',
#  'STATUS',
#  'QTR_ID',
#  'MONTH_ID',
#  'YEAR_ID',
#  'PRODUCTLINE',
#  'MSRP',
#  'PRODUCTCODE',
#  'CUSTOMERNAME',
#  'ADDRESSLINE1',
#  'ADDRESSLINE2',
#  'CITY',
#  'STATE',
#  'POSTALCODE',
#  'COUNTRY',
#  'TERRITORY',
#  'CONTACTLASTNAME',
#  'CONTACTFIRSTNAME',
#  'DEALSIZE']

# %%
print(data.columns)
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'ADDRESSLINE1',
#        'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'ADDRESSLINE1',
#        'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
data.tail(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2813 2004-09-09   Shipped       3         9     2004  ...
# ...

# %%
data.shape
# Out:
# (2823, 24)

# %%
print("NO of rows",data.shape[0])
# Out:
# NO of rows 2823

# %%
print("no of columns",data.shape[1])
# Out:
# no of columns 24

# %%
df=data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  ADDRESSLINE1      2823 non-null   object
#  15  ADDRESSLINE2      302 non-null    object
# ...

# %%
df.describe(include='all')
# Out:
# C:\Users\rjris\AppData\Local\Temp\ipykernel_21128\2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#          ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count    2823.000000      2823.000000  2823.000000      2823.000000
# unique           NaN              NaN          NaN              NaN
# top              NaN              NaN          NaN              NaN
# freq             NaN              NaN          NaN              NaN
# first            NaN              NaN          NaN              NaN
# last             NaN              NaN          NaN              NaN
# mean    10258.725115        35.092809    83.658544         6.466171
# std        92.085478         9.741443    20.174277         4.225841
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['YEAR_ID'].unique() #unique values
# Out:
# array([2003, 2004, 2005], dtype=int64)

# %%
df['YEAR_ID'].nunique() # number of unique values all over
# Out:
# 3

# %%
df['YEAR_ID'].value_counts() # count of unique values
# Out:
# 2004    1345
# 2003    1000
# 2005     478
# Name: YEAR_ID, dtype: int64

# %%
(df['PRICEEACH']>=65) & (df['PRICEEACH']<78) # values between 65-78 from priceeach column, results in boolean format
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822     True
# Name: PRICEEACH, Length: 2823, dtype: bool

# %%
df[(df['PRICEEACH']>=65) & (df['PRICEEACH']<78)] # values between 65-78 from priceeach column
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 21          10361               20      72.55               13  1451.00
# 23          10388               42      76.36                4  3207.12
# 74          10339               40      68.92                4  2756.80
# 100         10339               39      76.67                3  2990.13
# 126         10350               26      75.47                5  1962.22
# ...           ...              ...        ...              ...      ...
# 2763        10352               22      75.51                1  1661.22
# 2768        10401               28      72.55               11  2031.40
# 2789        10339               27      76.31                6  2060.37
# 2809        10248               23      65.52                9  1506.96
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
len(df[(df['PRICEEACH']>=65) & (df['PRICEEACH']<78)]) # count values between 65-78 from priceeach column
# Out:
# 344

# %%
sum(df['PRICEEACH'].between(65,78)) # count values between through between function
# Out:
# 346

# %%
df['PRICEEACH'].mean() # for finding avg value use mean()
# Out:
# 83.65854410201929

# %%
df['half_price']=df['PRICEEACH']/2 # new column as halfprice

# %%
df.drop(['half_price'],axis=1) # delete new column of halfprice
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
def PRICEEACH (x): # apply method function
    return x/2

# %%
df['half_price']= df['PRICEEACH'].apply(PRICEEACH) # uses of apply menthod function with new column name

# %%
df['half_price']
# Out:
# 0       47.850
# 1       40.675
# 2       47.370
# 3       41.630
# 4       50.000
#          ...
# 2818    50.000
# 2819    50.000
# 2820    50.000
# 2821    31.120
# 2822    32.760
# Name: half_price, Length: 2823, dtype: float64

# %%
df.drop(['half_price'],axis=1)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['HALF_PRICE']=df['PRICEEACH'].apply(lambda x: x/2) # appling lambda () to prepare apply method in short form

# %%
df.dtypes # type of data
# Out:
# ORDERNUMBER                  int64
# QUANTITYORDERED              int64
# PRICEEACH                  float64
# ORDERLINENUMBER              int64
# SALES                      float64
# ORDERDATE           datetime64[ns]
# QTR_ID                       int64
# MONTH_ID                     int64
# YEAR_ID                      int64
# PRODUCTLINE                 object
# MSRP                         int64
# PRODUCTCODE                 object
# CUSTOMERNAME                object
# ADDRESSLINE1                object
# ADDRESSLINE2                object
# CITY                        object
# STATE                       object
# POSTALCODE                  object
# COUNTRY                     object
# TERRITORY                   object
# CONTACTLASTNAME             object
# CONTACTFIRSTNAME            object
# DEALSIZE                    object
# half_price                 float64
# dtype: object

# %%
df['STATUS'].apply(len) # apply menthod
# Out:
# 0       7
# 1       7
# 2       7
# 3       7
# 4       7
#        ..
# 2818    7
# 2819    7
# 2820    8
# 2821    7
# 2822    7
# Name: STATUS, Length: 2823, dtype: int64

# %%
df['STATUS'].value_counts()
# Out:
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: STATUS, dtype: int64

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  ADDRESSLINE2  \
# ...

# %%
df['STATUS']
# Out:
# 0                     [Done]
# 1                     [Done]
# 2                     [Done]
# 3                     [Done]
# 4                     [Done]
#                 ...
# 2818                  [Done]
# 2819                  [Done]
# 2820    [Resolved 3rd party]
# 2821                  [Done]
# 2822                     NaN
# Name: STATUS, Length: 2823, dtype: object

# %%
df.drop(['STATUS','HALF_PRICE'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'ADDRESSLINE1', 'ADDRESSLINE2',
#        'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE', 'half_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %%
df.sort_values(by=['PRICEEACH','ORDERDATE'],ascending=False) #sorting in decending order, list[] req to use when more- 
# then 1coumn is require to manupulate.
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 53          10424               50     100.00                6  12001.00
# 160         10425               38     100.00               12   5894.94
# 239         10424               49     100.00                3   7969.36
# 393         10425               33     100.00                4   4692.60
# 447         10424               54     100.00                5   7182.00
# ...           ...              ...        ...              ...       ...
# 1546        10193               26      29.21               10    759.46
# 1551        10280               20      28.88               12    577.60
# 1724        10195               32      28.29                7    905.28
# 1543        10162               37      27.22                5   1007.14
# 1563        10420               45      26.88                1   1209.60
#
#       ORDERDATE  QTR_ID  MONTH_ID  YEAR_ID       PRODUCTLINE  ...  \
# ...

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  ADDRESSLINE2  \
# ...

# %%
df[df['PRODUCTLINE']=='Ships'] [['QUANTITYORDERED','ORDERDATE']]  # quantity-ord & od for ships only
# Out:
#       QUANTITYORDERED  ORDERDATE
# 935                41 2003-02-17
# 936                21 2003-04-28
# 937                40 2003-06-16
# 938                46 2003-08-10
# 939                44 2003-10-06
# ...               ...        ...
# 2818               20 2004-12-02
# 2819               29 2005-01-31
# 2820               43 2005-03-01
# 2821               34 2005-03-28
# 2822               47 2005-05-06
#
# [234 rows x 2 columns]

# %%
df[df['PRODUCTLINE'].isin(['Ships'])] [['QUANTITYORDERED','ORDERDATE']] # "using isin() method" 
                                                                        #quantity-ord & od for ships only
# Out:
#       QUANTITYORDERED  ORDERDATE
# 935                41 2003-02-17
# 936                21 2003-04-28
# 937                40 2003-06-16
# 938                46 2003-08-10
# 939                44 2003-10-06
# ...               ...        ...
# 2818               20 2004-12-02
# 2819               29 2005-01-31
# 2820               43 2005-03-01
# 2821               34 2005-03-28
# 2822               47 2005-05-06
#
# [234 rows x 2 columns]

# %%
df=data

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
len(df[df['STATUS']=='Cancelled'])  # len () use for count of cancelled
# Out:
# 60

# %%
df['STATUS'].value_counts()
# Out:
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: STATUS, dtype: int64

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'ADDRESSLINE1',
#        'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
df[df['ADDRESSLINE1'].str.contains('Rd')] # in the address 'Rd' is the sting to clooect the 'Rd' data use str.contains()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 11          10237               23     100.00                7  2333.12
# 12          10251               28     100.00                2  3188.64
# 66          10251               44     100.00                5  5756.52
# 91          10237               39     100.00                9  7023.90
# 92          10251               43     100.00                4  7078.23
# 251         10237               32     100.00                6  4193.28
# 252         10251               46     100.00                1  7552.28
# 284         10324               27      54.33                1  1466.91
# 386         10324               26      58.38                7  1517.88
# 475         10102               39     100.00                2  4808.31
# 501         10102               41      50.14                1  2055.74
# 672         10324               47     100.00                8  7207.45
# ...

# %%
df[(df['SALES'].between(800,4500))] [['SALES','ORDERDATE','QUANTITYORDERED']]
# Out:
#         SALES  ORDERDATE  QUANTITYORDERED
# 0     2871.00 2003-02-24               30
# 1     2765.90 2003-05-07               34
# 2     3884.34 2003-07-01               41
# 3     3746.70 2003-08-25               45
# 5     3479.76 2003-10-28               36
# ...       ...        ...              ...
# 2817  4080.72 2004-11-21               42
# 2818  2244.40 2004-12-02               20
# 2819  3978.51 2005-01-31               29
# 2821  2116.16 2005-03-28               34
# 2822  3079.44 2005-05-06               47
#
# [2098 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'ADDRESSLINE1',
#        'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
df.head(30)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# ...

# %%
#deal size is small and from paris
len(df[(df['DEALSIZE']=='Small') & (df['SALES']<1000)] [['TERRITORY','COUNTRY']])
# Out:
# 50

# %%
df['ORDERDATE']=pd.to_datetime(df["ORDERDATE"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  ADDRESSLINE1      2823 non-null   object
#  15  ADDRESSLINE2      302 non-null    object
# ...

# %%
def fun():
    count=0
    for date in df['ORDERDATE']:
     if date.split[3:6]=='2005':
        count=count+1
    print(count)

# %%
df['ORDERDATE']
# Out:
# 0      2003-02-24
# 1      2003-05-07
# 2      2003-07-01
# 3      2003-08-25
# 4      2003-10-10
#           ...
# 2818   2004-12-02
# 2819   2005-01-31
# 2820   2005-03-01
# 2821   2005-03-28
# 2822   2005-05-06
# Name: ORDERDATE, Length: 2823, dtype: datetime64[ns]

# %%
df['PRODUCTCODE']
# Out:
# 0       S10_1678
# 1       S10_1678
# 2       S10_1678
# 3       S10_1678
# 4       S10_1678
#           ...
# 2818    S72_3212
# 2819    S72_3212
# 2820    S72_3212
# 2821    S72_3212
# 2822    S72_3212
# Name: PRODUCTCODE, Length: 2823, dtype: object

# %%
df['PRODUCTCODE'].apply(lambda x:x.split('_')[1]).value_counts().head(3)
# Out:
# 3856    53
# 3232    52
# 1949    28
# Name: PRODUCTCODE, dtype: int64

# %%
list1=[]
for productcode in df['PRODUCTCODE']:
    list1.append(productcode.split('_')[1])

# %%
df['temp']=list1

# %%
df.head(1)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30       95.7                2  2871.0
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  CITY  \
# 0 2003-02-24  Shipped       1         2     2003  ...          NaN   NYC
#
#   STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 0    NY      10022     USA       NaN              Yu             Kwai
#
#   DEALSIZE  temp
# 0    Small  1678
#
# [1 rows x 25 columns]

# %%
df['temp'].value_counts().head(3)
# Out:
# 3856    53
# 3232    52
# 1949    28
# Name: temp, dtype: int64
