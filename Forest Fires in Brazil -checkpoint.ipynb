# %%
import pandas as pd
import numpy as np
import seaborn as sys
import matplotlib.pyplot as plt

# %% [markdown]
# # Forest Fires in Brazil dataset (from 1998-2017)

# %%
df=pd.read_csv("C:\\Users\\rjris\\Downloads\\python data set\\amazon.csv",encoding="ISO-8859-1",parse_dates=['date'])
# use encoading ="ISO-8859-1" to elemenating the encoading error
# parse_dates is used for changing the date format in datetime

# %%
df
# Out:
#       year      state     month  number       date
# 0     1998       Acre   Janeiro     0.0 1998-01-01
# 1     1999       Acre   Janeiro     0.0 1999-01-01
# 2     2000       Acre   Janeiro     0.0 2000-01-01
# 3     2001       Acre   Janeiro     0.0 2001-01-01
# 4     2002       Acre   Janeiro     0.0 2002-01-01
# ...    ...        ...       ...     ...        ...
# 6449  2012  Tocantins  Dezembro   128.0 2012-01-01
# 6450  2013  Tocantins  Dezembro    85.0 2013-01-01
# 6451  2014  Tocantins  Dezembro   223.0 2014-01-01
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01
#
# [6454 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 252.2+ KB

# %%
df.shape
# Out:
# (6454, 5)

# %% [markdown]
# # Checking the dublicate rows

# %%
df.isnull().sum()*100/len(df)
# Out:
# year      0.0
# state     0.0
# month     0.0
# number    0.0
# date      0.0
# dtype: float64

# %%
sys.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking duplicate values and eleminating

# %%
df.duplicated().sum() # for checking we use duplicated()
# Out:
# 0

# %%
df=df.drop_duplicates() # for eleminating we use duplicates()

# %%
6454-6422
# Out:
# 32

# %%
 df
# Out:
#       year      state     month  number       date
# 0     1998       Acre   Janeiro     0.0 1998-01-01
# 1     1999       Acre   Janeiro     0.0 1999-01-01
# 2     2000       Acre   Janeiro     0.0 2000-01-01
# 3     2001       Acre   Janeiro     0.0 2001-01-01
# 4     2002       Acre   Janeiro     0.0 2002-01-01
# ...    ...        ...       ...     ...        ...
# 6449  2012  Tocantins  Dezembro   128.0 2012-01-01
# 6450  2013  Tocantins  Dezembro    85.0 2013-01-01
# 6451  2014  Tocantins  Dezembro   223.0 2014-01-01
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01
#
# [6422 rows x 5 columns]

# %%
df.describe()
# Out:
#               year       number
# count  6422.000000  6422.000000
# mean   2007.490969   108.815178
# std       5.731806   191.142482
# min    1998.000000     0.000000
# 25%    2003.000000     3.000000
# 50%    2007.000000    24.497000
# 75%    2012.000000   114.000000
# max    2017.000000   998.000000

# %% [markdown]
# # Total number of Fires Registered

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'month_new'], dtype='object')

# %%
df.shape
# Out:
# (6422, 6)

# %%
# 6422 numbers of fires repoted or registered.

# %% [markdown]
# # Which Month Maximum Number Fire were Repoted

# %%
df1=df.groupby('month') ['number'].sum().reset_index().sort_values(by='number',ascending=False)
df1
# Out:
#         month     number
# 5       Julho  92319.113
# 10    Outubro  88681.579
# 1      Agosto  88050.435
# 9    Novembro  85508.054
# 11   Setembro  58578.305
# 2    Dezembro  57535.480
# 6       Junho  55997.675
# 4     Janeiro  47681.844
# 7        Maio  34725.363
# 3   Fevereiro  30839.050
# 8       Março  30709.405
# 0       Abril  28184.770

# %%
# In the month of july max no of fire were repoted.

# %%
sys.barplot(x='month',y='number',data=df1)
plt.xticks(rotation=65)
plt.title('Fire Incedent Repoted on Monthly Basis')
plt.show()

# %% [markdown]
# # In which Year Max Number of Forest Fire were Repoted

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'month_new'], dtype='object')

# %%
df2=df.groupby('year') ['number'].sum().reset_index().sort_values(by='number',ascending=False)
df2
# Out:
#     year     number
# 5   2003  42760.674
# 18  2016  42212.229
# 17  2015  41208.292
# 14  2012  40084.860
# 16  2014  39621.183
# 11  2009  39116.178
# 6   2004  38450.163
# 4   2002  37390.600
# 12  2010  37037.449
# 19  2017  36619.624
# 15  2013  35137.118
# 7   2005  35004.965
# 13  2011  34633.545
# 8   2006  33824.161
# 9   2007  33028.413
# 10  2008  29378.964
# 3   2001  29054.612
# 2   2000  27351.251
# 1   1999  26882.821
# 0   1998  20013.971

# %%
plt.figure(figsize=(16,5))
sys.barplot(x='year',y='number',data=df2)
plt.title('Fire Incedent Repoted on Yearly Basis')
plt.show()

# %% [markdown]
# # In which State Max Number of Forest Fire were Repoted

# %%
df3=df.groupby('state') ['number'].sum().reset_index().sort_values(by='number',ascending=False)
df3
# Out:
#                state     number
# 10       Mato Grosso  96246.028
# 12           Paraiba  52426.918
# 20         Sao Paulo  51121.198
# 16               Rio  45094.865
# 4              Bahia  44746.226
# 15              Piau  37803.747
# 8              Goias  37695.520
# 11      Minas Gerais  37475.258
# 22         Tocantins  33707.885
# 3           Amazonas  30650.129
# 5              Ceara  30428.063
# 9           Maranhao  25129.131
# 13              Pará  24512.144
# 14        Pernambuco  24498.000
# 18           Roraima  24385.074
# 19    Santa Catarina  24359.852
# 2              Amapa  21831.576
# 17          Rondonia  20285.429
# 0               Acre  18464.030
# 7     Espirito Santo   6546.000
# 1            Alagoas   4606.000
# 6   Distrito Federal   3561.000
# 21           Sergipe   3237.000

# %%
plt.figure(figsize=(16,5))
sys.barplot(x='state',y='number',data=df3)
plt.xticks(rotation=75)
plt.title('Fire Incedent Repoted on Yearly Basis',size=25,color='Red')
plt.show()

# %% [markdown]
# # Total Number of Fire Repoted in Amazonas

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
df[df['state']=='Amazonas'] ['number'].sum()
# Out:
# 30650.129

# %% [markdown]
# # Number of Fire Repoted in Amazonas year wise

# %%
data1=df[df['state']=='Amazonas']
data2= data.groupby('year')['number'].sum().reset_index()
data2
# Out:
#     year    number
# 0   1998   946.000
# 1   1999  1061.000
# 2   2000   853.000
# 3   2001  1297.000
# 4   2002  2852.000
# 5   2003  1524.268
# 6   2004  2298.207
# 7   2005  1657.128
# 8   2006   997.640
# 9   2007   589.601
# 10  2008  2717.000
# 11  2009  1320.601
# 12  2010  2324.508
# 13  2011  1652.538
# 14  2012  1110.641
# 15  2013   905.217
# 16  2014  2385.909
# 17  2015  1189.994
# 18  2016  2060.972
# 19  2017   906.905

# %%
plt.figure(figsize=(16,5))
sys.barplot(x='year',y='number',data=data2)
plt.title('Total Number of Fire Repoted in Amazonas',size=25,color='Red')
# Out:
# Text(0.5, 1.0, 'Total Number of Fire Repoted in Amazonas')

# %% [markdown]
# # Number of Fire Repoted in Amazonas day wise

# %%
data1=df[df['state']=='Amazonas']
day=data1.groupby(data1['date'].dt.dayofweek).sum().number
import calendar
day.index=[calendar.day_name[x] for x in range(0,7)]
day.reset_index()
# Out:
#        index    number
# 0     Monday  1886.601
# 1    Tuesday  6474.217
# 2  Wednesday  3910.177
# 3   Thursday  5754.802
# 4     Friday  5446.480
# 5   Saturday  4162.666
# 6     Sunday  3015.186

# %% [markdown]
# # Total No of Fires were Repoted in 2015 & Visualize Data Based on Each Month

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
fire_repoted=df[df['year']==2015].groupby('month') ['number'].sum().reset_index()
fire_repoted
# Out:
#         month    number
# 0       Abril  2573.000
# 1      Agosto  4363.125
# 2    Dezembro  4088.522
# 3   Fevereiro  2309.000
# 4     Janeiro  4635.000
# 5       Julho  4364.392
# 6       Junho  3260.552
# 7        Maio  2384.000
# 8       Março  2202.000
# 9    Novembro  4034.518
# 10    Outubro  4499.525
# 11   Setembro  2494.658

# %%
plt.figure(figsize=(16,5))
sys.barplot(x='month',y='number',data=fire_repoted)
plt.xticks(rotation=65)
plt.title("Tot.Number of Fire Repoted in 2015,Based on Each Month",size=25,color='Red')
plt.show()

# %% [markdown]
# # AVerage No. of Fires were Repoted from Highest to lowest (State-Wise)

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
w=df.groupby('state')['number'].mean().sort_values(ascending=False).reset_index()
w
# Out:
#                state      number
# 0          Sao Paulo  213.896226
# 1        Mato Grosso  203.479975
# 2              Bahia  187.222703
# 3               Piau  158.174674
# 4              Goias  157.721841
# 5       Minas Gerais  156.800243
# 6          Tocantins  141.037176
# 7           Amazonas  128.243218
# 8              Ceara  127.314071
# 9            Paraiba  111.073979
# 10          Maranhao  105.142808
# 11              Pará  102.561272
# 12        Pernambuco  102.502092
# 13           Roraima  102.029598
# 14    Santa Catarina  101.924067
# 15             Amapa   91.345506
# 16          Rondonia   84.876272
# 17              Acre   77.255356
# 18               Rio   64.698515
# 19    Espirito Santo   27.389121
# 20           Alagoas   19.271967
# 21  Distrito Federal   14.899582
# 22           Sergipe   13.543933

# %%
plt.figure(figsize=(16,5))
sys.barplot(x='state',y='number',data=w)
plt.xticks(rotation=65)
plt.title("Average No. of Fire were Repoted in State Wise",size=25,color='Red')
plt.show()

# %% [markdown]
# # Find the States Names were Fire Repoted in December Month

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
df[df['month']=='Dezembro']['state'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)
