# %%
import pandas as pd
import numpy as np
import seaborn as sys
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\rjris\\Downloads\\python data set\\udemy_courses.csv",parse_dates=['published_timestamp'])
print(df)
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# # shape of data

# %%
df.shape
# Out:
# (3678, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum() # Here sum() is used to get the total null values of the columns
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sys.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # find and delete dublicate data and delete

# %%
dup=df[df.duplicated()]

# %%
df=df.drop_duplicates()

# %%
dup
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %% [markdown]
# # Number of courses per subject

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['subject'].value_counts() # value_counts() will display the unique counts
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
 sys.countplot(df['subject']) # countplot use in catagorical value
# Out:
# C:\Users\rjris\.ipython\extensions\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='count'>

# %%
sys.countplot(df['subject'])
plt.title("Number of courses",fontsize=24)
plt.xticks(rotation=65)
# Out:
# C:\Users\rjris\.ipython\extensions\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Business Finance'),
#   Text(1, 0, 'Graphic Design'),
#   Text(2, 0, 'Musical Instruments'),
#   Text(3, 0, 'Web Development')])

# %% [markdown]
# # For which level udemy is providing the courses

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sys.countplot(df['level'])
plt.blabel('LEVEL',fontsize=14)
# Out:
# C:\Users\rjris\.ipython\extensions\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_808\561166019.py in <module>
#       1 sys.countplot(df['level'])
# ----> 2 plt.blabel('LEVEL',fontsize=14)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'blabel'

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
sys.countplot(df['is_paid'])
# Out:
# C:\Users\rjris\.ipython\extensions\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='is_paid', ylabel='count'>

# %% [markdown]
# # which courses has more lecture(free or paid)

# %%
df.groupby('is_paid').mean()
# Out:
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %% [markdown]
# # which courses has higher no of suscriber (both paid or free)

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.groupby('is_paid') ['num_lectures'].max()
# Out:
# is_paid
# False    145
# True     779
# Name: num_lectures, dtype: int64

# %%
sys.barplot(x="is_paid",y="num_lectures",data=df)
# Out:
# <AxesSubplot:xlabel='is_paid', ylabel='num_lectures'>

# %% [markdown]
# # which level has higher no of suscribers

# %%
import matplotlib.pyplot as plt
import seaborn as sys

# %%
df.groupby('level') ['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
sys.barplot(x="level",y="num_subscribers",data=df)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # Most popular course title

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['num_subscribers'].max()
# Out:
# 268923

# %%
df[df['num_subscribers'].max()==df['num_subscribers']] ['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# # Top 10 most popular courses as per number of subscriber

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
top_10=df.sort_values(by="num_subscribers",ascending=False).head(10)

# %%
top10
# Out:
# 2827                 Learn HTML5 Programming From Scratch
# 3032                       Coding for Entrepreneurs Basic
# 3230                           The Web Developer Bootcamp
# 2783    Build Your First Website in 1 Week with HTML5 ...
# 3232                The Complete Web Developer Course 2.0
# 1896                Free Beginner Electric Guitar Lessons
# 2589    Web Design for Web Developers: Build Beautiful...
# 2619               Learn Javascript & JQuery From Scratch
# 3289    Practical PHP: Master the Basics and Code Dyna...
# 3247            JavaScript: Understanding the Weird Parts
# Name: course_title, dtype: object

# %%
plt.figure(figsize=(10,4))
sys.barplot(x="num_subscribers",y="course_title",data=top_10)
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# # Courses having highest no of reviews

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
sys.barplot(x="subject", y="num_subscribers",data=df)
# Out:
# <AxesSubplot:xlabel='subject', ylabel='num_subscribers'>

# %% [markdown]
# # Does price affects the number of reviews

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sys.scatterplot(x="price", y="num_reviews",data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# # Find total number of courses releted to python

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
len(df[df['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %% [markdown]
# # Top 10 python courses as per subscriber

# %%
data=df[df['course_title'].str.contains('python',case=False)].sort_values(by="num_subscribers",ascending=False).head(10)

# %%
plt.figure(figsize=(10,4))
sys.barplot(x="num_subscribers",y="course_title",data=data)
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# # In which year higher number of courses were posted

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['Year']=df['published_timestamp'].dt.year

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
sys.countplot('Year',data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# # Display category- wise count of posted subjects(year wise)

# %%
df.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64
